# %%
from PIL import Image
import numpy as np
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display
from utils import parse_voc_annotation, draw_bbox_on_img
import torch

# %%
parse_voc_annotation("../data/labels/maksssksksss9.xml")
# Out:
# [[-1, 148, 75, 201, 133], [0, 27, 78, 56, 106]]

# %%
# CLASSES = [ "without_mask", "with_mask"]
# With mask;
# Without mask;
# Mask worn incorrectly.


WITH_MASK = 1
WITHOUT_MASK = 0
MASK_WORN_INCORRECTLY = -1

# %%
# img_one_bbox1 = [79,105,109,142]
# 'without_mask', 'bbox': [79, 105, 109, 142]
# bbox_coordinates = [[0, 79, 105, 109, 142],[1,185, 100, 226, 144],[0, 325, 90, 360, 141]]
# draw_bbox_on_img("../data/images/maksssksksss0.png", bbox_coordinates)

# another example
# bbox_coordinates = [[1, 52, 53, 73, 76],[1, 72, 53, 92, 75],[1, 112, 51, 120, 68],[1, 155, 60, 177, 83],[1, 189, 59, 210, 80],[1, 235, 57, 257, 78],[1, 289, 60, 309, 83],[1, 313, 68, 333, 90],  [1, 351, 35, 364, 59]]
# draw_bbox_on_img("../data/images/maksssksksss9.png", bbox_coordinates)

# another
# maksssksksss9
# bbox_coordinates = [[-1, 148, 75, 201, 133], [0, 27, 78, 56, 106]]
# draw_bbox_on_img("../data/images/maksssksksss9.png", bbox_coordinates)


# another
bbox_coordinates = [[-1, 181, 54, 273, 162], [1, 99, 87, 176, 165], [1, 289, 99, 355, 233]]
draw_bbox_on_img("../data/images/maksssksksss99.png", bbox_coordinates)
# Out:
# <PIL.Image.Image image mode=RGB size=400x267>

# %%
parse_voc_annotation("../data/labels/maksssksksss99.xml")
# Out:
# [[-1, 181, 54, 273, 162], [1, 99, 87, 176, 165], [1, 289, 99, 355, 233]]

# %%
i = "with_mask"
1 if i == "with_mask" else 0
