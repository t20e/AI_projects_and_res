# %% [markdown]
# # Chain Rule Derivative

# %% [markdown]
# In machine learning, especially deep learning, models are built from multiple layers. Where each layer applies an adjustment to the output of the previous layer.

# %% [markdown]
# It states that if we have a function, $y=f(g(x))$, where $g$ is a function of $x$, and $f$ is a function of $g$, then the derivative with respect to $x$ is given by:
#
# $$\frac{dy}{dx} = \frac{df}{dg} * \frac{dg}{dx}$$
#
# This enables us to compute:
# * The derivative of the loss with respect to the output
# * The derivative of the output with respect to the learned parameters weights $(w)$ and biases $(b)$.

# %% [markdown]
# **Network:**
# <p align="center">
#     <img src="../showcase_images/chain_rule_network.png" alt="network" width="80%">
# </p>

# %% [markdown]
# * Input layer with 2 neurons (2 features)
# * One hidden layer with 2 weight neurons and one bias neuron
# * One output layer with 1 neuron.

# %% [markdown]
# <!-- TODO https://www.geeksforgeeks.org/machine-learning/chain-rule-derivative-in-machine-learning/ -->
